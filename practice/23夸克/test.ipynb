# %%
import json
f = open("kuake.json", 'r')
test = f.read()

# %%
json.loads(test)
# Out:
#    {'year': '2019',
#       'aos': ['理科', '文科'],
#       'max_score': '480',
#       'score_type': ''},
#      {'year': '2020',
#       'aos': ['理科', '文科'],
#       'max_score': '480',
#       'score_type': ''},
#      {'year': '2021',
#       'aos': ['首选物理', '首选历史'],
#       'max_score': '750',
#       'score_type': ''}],
#     'defaultYear': '2020',
#     'controlAos': ['理科', '文科', '首选物理', '首选历史']},
#    {'id': '40',
#     'province': '湖南',
#     'years': [{'year': '2015',
#       'aos': ['理科', '文科'],
#       'max_score': '750',
#       'score_type': ''},
#      {'year': '2016',
#       'aos': ['理科', '文科'],
#       'max_score': '750',
#       'score_type': ''},
#      {'year': '2017',
#       'aos': ['理科', '文科'],
#       'max_score': '750',
#       'score_type': ''},
#      {'year': '2018',
#       'aos': ['理科', '文科'],
#       'max_score': '750',
#       'score_type': ''},
#      {'year': '2019',
#       'aos': ['理科', '文科'],
#       'max_score': '750',
#       'score_type': ''},
# ...
